# %%
import pandas as pd
# %matplotlib notebook
import matplotlib.pyplot as plt
import seaborn as sns
covid_data = pd.read_csv('C:\\Users\\양연진\\Desktop\\owid-covid-data.csv', engine = 'python')
date1 = pd.to_datetime(covid_data['date'], format= '%Y-%m-%d')

d1 = covid_data.loc[:,['date','total_cases']]
s1 = d1.groupby('date')['total_cases'].sum()
plt.figure(figsize=(10,5))
s1.plot()

plt.title("Number of the confirmed cases")
plt.xlabel("Date")
plt.ylabel("Count")
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0, 0.5, 'Count')

# %%
d2 = covid_data.loc[:,['continent','date','total_cases']]

s2 = d2.groupby(['continent','date'])['total_cases'].sum()

s2_Asia = s2.loc[['Asia'],:]
s2_North_America = s2.loc[['North America'],:]
s2_Europe = s2.loc[['Europe'],:]
s2_Oceania = s2.loc[['Oceania'],:]
s2_Africa = s2.loc[['Africa'],:]
s2_South_America = s2.loc[['South America'],:]

plt.figure(figsize=(20,10))
s2_Asia.plot()
s2_North_America.plot()
s2_Europe.plot()
s2_Oceania.plot()
s2_Africa.plot()
s2_South_America.plot()



plt.legend(['Asia', 'North America', 'Europe', 'Oceania', 'Africa', 'South America'])
plt.title("Number of the confirmed cases by continent")
plt.xlabel("Date")
plt.ylabel("Count")

#2번 문제 대륙별 날자별 확진자 수_ date에 South America가 없어지려면?
# Out:
# <img src="data:image/png;base64,..." width="2000">
# Text(0, 0.5, 'Count')

# %%
d3 = covid_data.loc[:,['date','total_cases_per_million','human_development_index']]
d4 = d3.groupby('date')[['total_cases_per_million','human_development_index']]
d5 = d4.get_group('2021-01-25')
hexbin = sns.jointplot(x=d5['human_development_index'], y=d5['total_cases_per_million'], kind='hex')

#3번 문제 가장 최근 일자 기준 HDI(인간개발지수)와 확진자 비율 간의 상관관계_y축이...
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
covid_data.info()

import numpy as np

d6 = covid_data.groupby('date')[['location','total_cases','total_deaths','hospital_beds_per_thousand']]
d7 = d6.get_group('2021-01-25')
d7 = d7.dropna()
print(d7)
mortality = (total_deaths / total_cases) * 1000

# 현재 확진자 중 사망자 수 그리고 나라별로 묶어서 병상수와 비교 total_deaths / total_cases * 1000
# 좀 더 보완해서 다시 올려도 될까요??
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62239 entries, 0 to 62238
# Data columns (total 55 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               61885 non-null  object
#  1   continent                              61515 non-null  object
#  2   location                               62239 non-null  object
#  3   date                                   62239 non-null  object
#  4   total_cases                            61642 non-null  float64
#  5   new_cases                              61635 non-null  float64
#  6   new_cases_smoothed                     60675 non-null  float64
#  7   total_deaths                           53092 non-null  float64
#  8   new_deaths                             53091 non-null  float64
#  9   new_deaths_smoothed                    60675 non-null  float64
#  10  total_cases_per_million                61288 non-null  float64
#  11  new_cases_per_million                  61281 non-null  float64
#  12  new_cases_smoothed_per_million         60326 non-null  float64
#  13  total_deaths_per_million               52751 non-null  float64
#  14  new_deaths_per_million                 52750 non-null  float64
#  15  new_deaths_smoothed_per_million        60326 non-null  float64
#  16  reproduction_rate                      50035 non-null  float64
#  17  icu_patients                           6856 non-null   float64
#  18  icu_patients_per_million               6856 non-null   float64
#  19  hosp_patients                          8114 non-null   float64
#  20  hosp_patients_per_million              8114 non-null   float64
#  21  weekly_icu_admissions                  672 non-null    float64
#  22  weekly_icu_admissions_per_million      672 non-null    float64
#  23  weekly_hosp_admissions                 991 non-null    float64
#  24  weekly_hosp_admissions_per_million     991 non-null    float64
#  25  total_tests                            28722 non-null  float64
#  26  new_tests                              28902 non-null  float64
#  27  total_tests_per_thousand               28722 non-null  float64
#  28  new_tests_per_thousand                 28902 non-null  float64
#  29  new_tests_smoothed                     32593 non-null  float64
#  30  new_tests_smoothed_per_thousand        32593 non-null  float64
#  31  positive_rate                          30771 non-null  float64
#  32  tests_per_case                         30282 non-null  float64
#  33  tests_units                            33792 non-null  object
#  34  total_vaccinations                     973 non-null    float64
#  35  new_vaccinations                       765 non-null    float64
#  36  new_vaccinations_smoothed              1263 non-null   float64
#  37  total_vaccinations_per_hundred         973 non-null    float64
#  38  new_vaccinations_smoothed_per_million  1263 non-null   float64
#  39  stringency_index                       55923 non-null  float64
#  40  population                             61885 non-null  float64
#  41  population_density                     60577 non-null  float64
#  42  median_age                             59210 non-null  float64
#  43  aged_65_older                          58524 non-null  float64
#  44  aged_70_older                          58875 non-null  float64
#  45  gdp_per_capita                         59247 non-null  float64
#  46  extreme_poverty                        40542 non-null  float64
#  47  cardiovasc_death_rate                  59850 non-null  float64
#  48  diabetes_prevalence                    60555 non-null  float64
#  49  female_smokers                         47227 non-null  float64
#  50  male_smokers                           46580 non-null  float64
#  51  handwashing_facilities                 29981 non-null  float64
#  52  hospital_beds_per_thousand             54965 non-null  float64
#  53  life_expectancy                        61567 non-null  float64
#  54  human_development_index                59513 non-null  float64
# dtypes: float64(50), object(5)
# memory usage: 26.1+ MB
#                   location  total_cases  total_deaths  \
# 336            Afghanistan      54672.0        2385.0
# 659                Albania      72812.0        1324.0
# 995                Algeria     105854.0        2866.0
# 1956   Antigua and Barbuda        201.0           6.0
# 2347             Argentina    1874801.0       47034.0
# ...                    ...          ...           ...
# 60951              Vietnam       1549.0          35.0
# 61321                World   99722272.0     2140085.0
# 61612                Yemen       2118.0         615.0
# 61926               Zambia      46146.0         660.0
# 62238             Zimbabwe      31646.0        1075.0
#
#        hospital_beds_per_thousand
# 336                         0.500
# 659                         2.890
# 995                         1.900
# 1956                        3.800
# 2347                        5.000
# ...                           ...
# 60951                       2.600
# 61321                       2.705
# 61612                       0.700
# 61926                       2.000
# 62238                       1.700
#
# [160 rows x 4 columns]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-105-492a52dbd6c2> in <module>
#       7 d7 = d7.dropna()
#       8 print(d7)
# ----> 9 mortality = (total_deaths / total_cases) * 1000
#      10
#      11 # 현재 확진자 중 사망자 수 그리고 나라별로 묶어서 병상수와 비교 total_deaths / total_cases * 1000
#
# NameError: name 'total_deaths' is not defined
