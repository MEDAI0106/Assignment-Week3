# %% [markdown]
# # 날짜 - 총 확진자 수 도전!

# %%
import pandas as pd
df = pd.read_csv('owid-covid-data.csv', parse_dates = [3])
#date를 문자열 - > datetime으로 바꿔줌 p.257
print(date.dtype) #위 사항 점검
from datetime import datetime
# Out:
# datetime64[ns]

# %%
subset1 = df[['date', 'total_cases'] ]
print(subset1.tail())
subset1.index = subset1['date'] #인덱스를 데이트로 p.258
# Out:
#             date  total_cases
# 62251 2021-01-21      30047.0
# 62252 2021-01-22      30523.0
# 62253 2021-01-23      31007.0
# 62254 2021-01-24      31320.0
# 62255 2021-01-25      31646.0

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %% [markdown]
# # 실패작

# %%
fig = plt.figure() #캔버스생성 
ax1 = fig.add_subplot(1, 1, 1) #캔버스 프레임 생성
ax1.plot(df['date'], df['total_cases']) #선그래프 생성
ax1.set_xlabel('date')
ax1.set_ylabel('total_people')
# Out:
# <img src="data:image/png;base64,..." width="862.9630239248646">
# Text(0, 0.5, 'total_people')

# %% [markdown]
# # 다시 도전

# %%
sccater_plot = plt.figure() # 산점도 그래프!?
ax1 = scatter_plot.add_subplot(1, 1, 1)
ax1.scatter(tips['date'], tips['total_cases']) # x변수, y변수 설정
ax1.set_title('total_by cases') 
ax1.set_xlabel('date')
ax1.set_ylabel('total_people')
# Out:
# <div id='d1b2070c-674c-497a-b145-4ab456597cd8'></div>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-100-e3c824a02720> in <module>
#       1 sccater_plot = plt.figure() # 산점도 그래프!?
# ----> 2 ax1 = scatter_plot.add_subplot(1, 1, 1)
#       3 ax1.scatter(tips['date'], tips['total_cases']) # x변수, y변수 설정
#       4 ax1.set_title('total_by cases')
#       5 ax1.set_xlabel('date')
#
# NameError: name 'scatter_plot' is not defined
